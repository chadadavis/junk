# %%
# Plot some random deviations (normal dist), with smoothing

import numpy as np
from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter1d

vals_n=10000
ys = np.random.randn(vals_n)
xs = [x for x in range(len(ys))]

sigma=60
ys_sm = gaussian_filter1d(ys, sigma=sigma)

plt.plot(xs, ys_sm)
plt.show()
# Out:
# /tmp/ipykernel_24221/3870103777.py:5: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter1d

# %% [markdown]
# ![image.png](attachment:image.png)
